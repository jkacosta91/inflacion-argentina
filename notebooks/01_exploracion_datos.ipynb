# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cargar los datos
df = pd.read_csv('../data/datos_macro.csv', parse_dates=['periodo'])

# %%
# Mostrar primeras filas
print("📌 Primeras filas del dataset:")
display(df.head())
# Out:
# 📌 Primeras filas del dataset:
#      periodo  IPC_General        EMAE  Tasa_Desempleo  \
# 0 2017-01-01     101.5859  136.632659           0.092
# 1 2017-01-02          NaN         NaN             NaN
# 2 2017-01-03          NaN         NaN             NaN
# 3 2017-01-04          NaN         NaN             NaN
# 4 2017-01-05          NaN         NaN             NaN
#
#    Saldo_Balanza_Comercial  Recursos_Tributarios  Despacho_de_Asfalto  \
# 0                    -53.0               55937.9            46.923391
# 1                      NaN                   NaN                  NaN
# 2                      NaN                   NaN                  NaN
# 3                      NaN                   NaN                  NaN
# 4                      NaN                   NaN                  NaN
#
#       RIPTE  Tipo_de_Cambio_USD  Tipo_de_Cambio_Multilateral
# 0  21048.21                16.1                    90.254396
# 1       NaN                16.1                    90.030213
# ...

# %%
# Info general
print("\n📋 Información general del dataset:")
df.info()
# Out:
# 📋 Información general del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   periodo                      192 non-null    datetime64[ns]
#  1   IPC_General                  96 non-null     float64
#  2   EMAE                         96 non-null     float64
#  3   Tasa_Desempleo               32 non-null     float64
#  4   Saldo_Balanza_Comercial      96 non-null     float64
#  5   Recursos_Tributarios         96 non-null     float64
#  6   Despacho_de_Asfalto          96 non-null     float64
#  7   RIPTE                        96 non-null     float64
#  8   Tipo_de_Cambio_USD           100 non-null    float64
#  9   Tipo_de_Cambio_Multilateral  100 non-null    float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 15.1 KB

# %%
# Valores faltantes
print("\n❓ Valores faltantes por columna:")
print(df.isnull().sum())
# Out:
# ❓ Valores faltantes por columna:
# periodo                          0
# IPC_General                     96
# EMAE                            96
# Tasa_Desempleo                 160
# Saldo_Balanza_Comercial         96
# Recursos_Tributarios            96
# Despacho_de_Asfalto             96
# RIPTE                           96
# Tipo_de_Cambio_USD              92
# Tipo_de_Cambio_Multilateral     92
# dtype: int64

# %%
# Estadísticas descriptivas
print("\n📊 Estadísticas descriptivas:")
display(df.describe())
# Out:
# 📊 Estadísticas descriptivas:
#                    periodo  IPC_General        EMAE  Tasa_Desempleo  \
# count                  192    96.000000   96.000000       32.000000
# mean   2019-01-18 04:45:00  1307.115384  144.260423        0.084689
# min    2017-01-01 00:00:00   101.585900  113.295034        0.057000
# 25%    2017-02-17 18:00:00   188.271375  137.696426        0.069750
# 50%    2017-04-06 12:00:00   393.694850  146.373029        0.085000
# 75%    2020-12-08 18:00:00  1151.685375  150.243742        0.096257
# max    2024-12-01 00:00:00  7694.007500  168.389209        0.131000
# std                    NaN  2037.598839    9.692134        0.018326
#
#        Saldo_Balanza_Comercial  Recursos_Tributarios  Despacho_de_Asfalto  \
# count                96.000000          9.600000e+01            96.000000
# mean                522.797233          6.149257e+05            35.932075
# min               -1832.736891          4.523780e+04             7.469340
# ...

# %%
# Correlación entre variables
print("\n📈 Matriz de correlación:")
corr = df.drop(columns='periodo').corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Matriz de Correlación entre Variables Económicas")
plt.show()
# Out:
# 📈 Matriz de correlación:

# %%
print(df.columns.tolist())
# Out:
# ['periodo', 'IPC_General', 'EMAE', 'Tasa_Desempleo', 'Saldo_Balanza_Comercial', 'Recursos_Tributarios', 'Despacho_de_Asfalto', 'RIPTE', 'Tipo_de_Cambio_USD', 'Tipo_de_Cambio_Multilateral']

# %%
columnas = [
    'IPC_General', 'EMAE', 'Tasa_Desempleo', 'RIPTE',
    'Tipo_de_Cambio_USD', 'Tipo_de_Cambio_Multilateral'  # sin 'Base_Monetaria_Total'
]

# %%
# Visualizar series temporales
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 12), sharex=True)
fig.suptitle("📈 Series Temporales Económicas (2017-2024)", fontsize=18, y=0.94)

columnas = [
    'IPC_General', 'EMAE', 'Tasa_Desempleo', 'RIPTE',
    'Tipo_de_Cambio_USD', 'Tipo_de_Cambio_Multilateral'  # sin 'Base_Monetaria_Total'
]
for i, col in enumerate(columnas):
    ax = axes[i // 2, i % 2]
    ax.plot(df['periodo'], df[col], label=col)
    ax.set_title(col)
    ax.set_ylabel("Valor")
    ax.grid(True)
    ax.legend()

for ax in axes[-1]:
    ax.set_xlabel("Fecha")

plt.tight_layout(rect=[0, 0, 1, 0.95])  # deja espacio para el título superior
plt.show()
# Out:
# C:\Users\jkaco\AppData\Local\Temp\ipykernel_25244\346858383.py:22: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])  # deja espacio para el título superior
